# %%
import pandas as pd             # For data manipulation and analysis
import numpy as np              # For numerical operations
import seaborn as sns           # For statistical data visualization
import matplotlib.pyplot as plt # For plotting graphs

from sklearn.model_selection import train_test_split   # For splitting dataset into training and test sets
from sklearn.metrics import accuracy_score             # For evaluating model accuracy
from sklearn.metrics import classification_report       # For a detailed classification performance report

import re          


# For regular expressions
import string                 # For string manipulation

# %%
data_fake = pd.read_csv(r'C:\Users\Achal\Documents\fake.csv')

data_true = pd.read_csv(r'C:\Users\Achal\Documents\true.csv')

# %%
data_fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
data_true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
data_fake["class"] = 0
data_true['class'] = 1

# %%
data_fake.shape, data_true.shape
# Out:
# ((23481, 5), (21417, 5))

# %%
# Display last 10 rows of the 'data_fake' dataset
print(data_fake.tail(10))

# Drop rows in a range from 23480 to 23470
for i in range(23480, 23470, -1):
    data_fake.drop([i], axis=0, inplace=True)

# Display last 10 rows of the 'data_true' dataset
print(data_true.tail(10))

# Drop rows in a range from 21416 to 21406
for i in range(21416, 21406, -1):
    data_true.drop([i], axis=0, inplace=True)
# Out:
#                                                    title  \
# 23471  Seven Iranians freed in the prisoner swap have...
# 23472                      #Hashtag Hell & The Fake Left
# 23473  Astroturfing: Journalist Reveals Brainwashing ...
# 23474          The New American Century: An Era of Fraud
# 23475  Hillary Clinton: ‘Israel First’ (and no peace ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 23471  21st Century Wire says This week, the historic...  Middle-east
# 23472   By Dady Chery and Gilbert MercierAll writers ...  Middle-east
# 23473  Vic Bishop Waking TimesOur reality is carefull...  Middle-east
# ...

# %%
data_fake.shape, data_true.shape
# Out:
# ((23471, 5), (21407, 5))

# %%
data_fake_manual_testing.head(10)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
# 5   Racist Alabama Cops Brutalize Black Boy While...
# 6   Fresh Off The Golf Course, Trump Lashes Out A...
# 7   Trump Said Some INSANELY Racist Stuff Inside ...
# 8   Former CIA Director Slams Trump Over UN Bully...
# 9   WATCH: Brand-New Pro-Trump Ad Features So Muc...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
# ...

# %%
data_true_manual_testing.head(10)
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
# 5  White House, Congress prepare for talks on spe...
# 6  Trump says Russia probe will be fair, but time...
# 7  Factbox: Trump on Twitter (Dec 29) - Approval ...
# 8         Trump on Twitter (Dec 28) - Global Warming
# 9  Alabama official to certify Senator-elect Jone...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# ...

# %%
data_merge = pd.concat([data_fake, data_true], axis = 0)
data_merge.head(10)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
# 5   Racist Alabama Cops Brutalize Black Boy While...
# 6   Fresh Off The Golf Course, Trump Lashes Out A...
# 7   Trump Said Some INSANELY Racist Stuff Inside ...
# 8   Former CIA Director Slams Trump Over UN Bully...
# 9   WATCH: Brand-New Pro-Trump Ad Features So Muc...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
# ...

# %%
data_merge.columns
# Out:
# Index(['title', 'text', 'subject', 'date', 'class'], dtype='object')

# %%
data = data_merge.drop(['title','subject','date'], axis = 1)

# %%
data.isnull().sum()
# Out:
# text     0
# class    0
# dtype: int64

# %%
data = data.sample(frac = 1)

# %%
data.head()
# Out:
#                                                     text  class
# 20781  Dinesh D Sousa warned us about Obama s reducti...      0
# 5085   WASHINGTON (Reuters) - White House spokesman S...      1
# 12128  JOHANNESBURG (Reuters) - The nearly man of Sou...      1
# 20957  MADRID (Reuters) - Spain is pushing for the Eu...      1
# 21033  BERLIN (Reuters) - German Chancellor Angela Me...      1

# %%
data.reset_index(inplace = True)
data.drop(['index'], axis = 1, inplace = True)

# %%
data.columns
# Out:
# Index(['text', 'class'], dtype='object')

# %%
data.head()
# Out:
#                                                 text  class
# 0  Dinesh D Sousa warned us about Obama s reducti...      0
# 1  WASHINGTON (Reuters) - White House spokesman S...      1
# 2  JOHANNESBURG (Reuters) - The nearly man of Sou...      1
# 3  MADRID (Reuters) - Spain is pushing for the Eu...      1
# 4  BERLIN (Reuters) - German Chancellor Angela Me...      1

# %%
def wordpt(text):
    text = text.lower()
    text = re.sub(r'\[.*?\]', '', text)
    text = re.sub(r"\W", " ", text)
    text = re.sub(r'https?://\S+|www\.\S+', '', text)
    text = re.sub(r'<.*?>+', '', text)
    text = re.sub(r'[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub(r'\n', '', text)
    text = re.sub(r'\W*\d\w*', '', text)
    return text

# %%
data['text'] =  data['text'].apply(wordpt)

# %%
x = data['text']
y = data['class']

# %%
z_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.25)

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

# Assuming you have a 'text' column and a 'class' column
x = data['text']
y = data['class']

# Split into train and test sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# Vectorize the text using TF-IDF
vectorization = TfidfVectorizer()
xv_train = vectorization.fit_transform(x_train)
xv_test = vectorization.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()
LR.fit(xv_train, y_train)
# Out:
# LogisticRegression()

# %%
pred_1r = LR.predict(xv_test)

# %%
LR.score (xv_test, y_test)
# Out:
# 0.986096256684492

# %%
print(classification_report (y_test, pred_1r))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5905
#            1       0.98      0.99      0.99      5315
#
#     accuracy                           0.99     11220
#    macro avg       0.99      0.99      0.99     11220
# weighted avg       0.99      0.99      0.99     11220

# %%
from sklearn.tree import DecisionTreeClassifier
DT = DecisionTreeClassifier()
DT.fit(xv_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dt = DT.predict(xv_test)

# %%
DT.score (xv_test, y_test)
# Out:
# 0.9948306595365419

# %%
print(classification_report (y_test, pred_1r))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5905
#            1       0.98      0.99      0.99      5315
#
#     accuracy                           0.99     11220
#    macro avg       0.99      0.99      0.99     11220
# weighted avg       0.99      0.99      0.99     11220

# %%
from sklearn.ensemble import GradientBoostingClassifier

GB = GradientBoostingClassifier(random_state=0)
GB.fit(xv_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=0)

# %%
predict_gb = GB.predict(xv_test)

# %%
GB. score (xv_test, y_test)
# Out:
# 0.9955436720142602

# %%
print(classification_report(y_test, predict_gb))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      5905
#            1       0.99      1.00      1.00      5315
#
#     accuracy                           1.00     11220
#    macro avg       1.00      1.00      1.00     11220
# weighted avg       1.00      1.00      1.00     11220

# %%
from sklearn.ensemble import RandomForestClassifier

RF = RandomForestClassifier(random_state=0)
RF.fit(xv_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
predict_rf = RF.predict(xv_test)

# %%
RF. score (xv_test, y_test)
# Out:
# 0.9885026737967915

# %%
print(classification_report(y_test, predict_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5905
#            1       0.99      0.99      0.99      5315
#
#     accuracy                           0.99     11220
#    macro avg       0.99      0.99      0.99     11220
# weighted avg       0.99      0.99      0.99     11220

# %%
def output_class(n):
    if n == 0:
        return "Fake News"
    elif n == 1:
        return "Not A Fake News"

def manual_testing(news):
    testing_news = {"text": [news]}
    new_def_test = pd.DataFrame(testing_news)
    
    # Apply text preprocessing
    new_def_test["text"] = new_def_test["text"].apply(wordpt)  # Ensure you call wordpt here, not wordopt
    
    # Transform the text using the trained vectorizer
    new_x_test = new_def_test["text"]
    new_xv_test = vectorization.transform(new_x_test)
    
    # Predict with different models
    pred_LR = LR.predict(new_xv_test)
    pred_DT = DT.predict(new_xv_test)
    pred_GB = GB.predict(new_xv_test)
    pred_RF = RF.predict(new_xv_test)

    # Print predictions for all models
    print("\n\nLR Prediction: {} \nDT Prediction: {} \nGBC Prediction: {} \nRFC Prediction: {}".format(
        output_class(pred_LR[0]),
        output_class(pred_DT[0]),
        output_class(pred_GB[0]),
        output_class(pred_RF[0])
    ))

# %%
news = input("Enter the news article: ")  # Just use input() directly
manual_testing(news)
# Out:
# Enter the news article:  news = input("Enter the news article: ")  # Just use input() directly manual_testing(news)
# LR Prediction: Fake News
# DT Prediction: Fake News
# GBC Prediction: Fake News
# RFC Prediction: Fake News

# %%
news = input("Enter the news article: ")  # Just use input() directly
manual_testing(news)
# Out:
# Enter the news article:  news = input("Enter the news article: ")  # Just use input() directly manual_testing(news)
# LR Prediction: Fake News
# DT Prediction: Fake News
# GBC Prediction: Fake News
# RFC Prediction: Fake News

# %%
news = input("Enter the news article: ")  # Just use input() directly
manual_testing(news)
# Out:
# Enter the news article:  news = input("Enter the news article: 1. India Launches Auction for Coal Bed Methane Blocks India has initiated an auction for three coal bed methane blocks and 55 small discovered oil and gas fields to boost domestic energy production. This move aims to reduce the country's heavy reliance on imports, as over 80% of its oil consumption is imported. Notably, Oil and Natural Gas Corp (ONGC) secured 11 blocks independently, and an additional block in collaboration with BP and Reliance Industries.")  # Just use input() directly manual_testing(news)
# LR Prediction: Fake News
# DT Prediction: Fake News
# GBC Prediction: Fake News
# RFC Prediction: Fake News

# %%
news = input("Enter the news article: ")  # Just use input() directly
manual_testing(news)
# Out:
# Enter the news article:  The Global Citizen NOW Action Summit, scheduled for April 30, 2025, in New York City, has announced its lineup. Prominent attendees include UN Deputy Secretary-General Amina Mohammed, Duchess of York Sarah Ferguson, scientist Bill Nye, and actress Laverne Cox. The summit aims to unite influential figures to tackle global poverty and promote sustainability and education.
# LR Prediction: Fake News
# DT Prediction: Fake News
# GBC Prediction: Fake News
# RFC Prediction: Not A Fake News

# %%
news = input("Enter the news article: ")  # Just use input() directly
manual_testing(news)
# Out:
# Enter the news article:  India's inflation rate in March 2025 likely remained steady at 3.60%, nearly unchanged from February’s 3.61%, according to a Reuters poll of 40 economists. This follows four consecutive months of declining inflation. While food prices remained flat, a 7% surge in gold prices—driven by investor demand amid U.S. trade tariff concerns—helped sustain inflation levels. Core inflation, which excludes food and energy, is estimated to have slightly increased to 4.1% from 3.9%-4.0% in February.
# LR Prediction: Not A Fake News
# DT Prediction: Not A Fake News
# GBC Prediction: Not A Fake News
# RFC Prediction: Not A Fake News
